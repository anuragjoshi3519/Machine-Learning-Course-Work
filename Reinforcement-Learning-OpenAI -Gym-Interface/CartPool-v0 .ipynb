# %%
import gym

# %%
env = gym.make('CartPole-v0')

# %%
env.reset()
for _ in range(1000):
    env.render()
    env.step(env.action_space.sample())
    
env.close()
# Out:
# /home/joshi_anurag/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
print(env.action_space)
print(env.observation_space)
print(env.reward_range)
# Out:
# Discrete(2)
# Box(4,)
# (-inf, inf)

# %% [markdown]
# ## Episodes

# %%
for e in range(100):   ## No.of episodes
    env.reset()
    for t in range(100):
        observation,reward,done,info=env.step(env.action_space.sample())
        env.render()
        if done==True:
            print("Episode {}/{} :: High Score - {}".format(e,100,t))
            break
env.close()
# Out:
# Episode 0/100 :: High Score - 36
# Episode 1/100 :: High Score - 13
# Episode 2/100 :: High Score - 25
# Episode 3/100 :: High Score - 17
# Episode 4/100 :: High Score - 14
# Episode 5/100 :: High Score - 15
# Episode 6/100 :: High Score - 10
# Episode 7/100 :: High Score - 10
# Episode 8/100 :: High Score - 35
# Episode 9/100 :: High Score - 21
# Episode 10/100 :: High Score - 16
# Episode 11/100 :: High Score - 17
# Episode 12/100 :: High Score - 11
# Episode 13/100 :: High Score - 16
# Episode 14/100 :: High Score - 14
# Episode 15/100 :: High Score - 9
# Episode 16/100 :: High Score - 20
# Episode 17/100 :: High Score - 29
# Episode 18/100 :: High Score - 16
# Episode 19/100 :: High Score - 17
# Episode 20/100 :: High Score - 14
# Episode 21/100 :: High Score - 13
# Episode 22/100 :: High Score - 13
# Episode 23/100 :: High Score - 17
# Episode 24/100 :: High Score - 36
# Episode 25/100 :: High Score - 11
# Episode 26/100 :: High Score - 13
# Episode 27/100 :: High Score - 27
# Episode 28/100 :: High Score - 18
# Episode 29/100 :: High Score - 32
# Episode 30/100 :: High Score - 10
# Episode 31/100 :: High Score - 12
# Episode 32/100 :: High Score - 16
# Episode 33/100 :: High Score - 34
# Episode 34/100 :: High Score - 36
# Episode 35/100 :: High Score - 33
# Episode 36/100 :: High Score - 11
# Episode 37/100 :: High Score - 31
# Episode 38/100 :: High Score - 26
# Episode 39/100 :: High Score - 13
# Episode 40/100 :: High Score - 13
# Episode 41/100 :: High Score - 8
# Episode 42/100 :: High Score - 12
# Episode 43/100 :: High Score - 9
# Episode 44/100 :: High Score - 24
# Episode 45/100 :: High Score - 35
# Episode 46/100 :: High Score - 20
# Episode 47/100 :: High Score - 21
# Episode 48/100 :: High Score - 18
# Episode 49/100 :: High Score - 15
# Episode 50/100 :: High Score - 22
# Episode 51/100 :: High Score - 29
# Episode 52/100 :: High Score - 19
# Episode 53/100 :: High Score - 59
# Episode 54/100 :: High Score - 14
# Episode 55/100 :: High Score - 18
# Episode 56/100 :: High Score - 15
# Episode 57/100 :: High Score - 8
# Episode 58/100 :: High Score - 51
# Episode 59/100 :: High Score - 10
# Episode 60/100 :: High Score - 37
# Episode 61/100 :: High Score - 24
# Episode 62/100 :: High Score - 20
# Episode 63/100 :: High Score - 18
# Episode 64/100 :: High Score - 25
# Episode 65/100 :: High Score - 37
# Episode 66/100 :: High Score - 27
# Episode 67/100 :: High Score - 30
# Episode 68/100 :: High Score - 28
# Episode 69/100 :: High Score - 10
# Episode 70/100 :: High Score - 11
# Episode 71/100 :: High Score - 12
# Episode 72/100 :: High Score - 21
# Episode 73/100 :: High Score - 9
# Episode 74/100 :: High Score - 23
# Episode 75/100 :: High Score - 16
# Episode 76/100 :: High Score - 16
# Episode 77/100 :: High Score - 8
# Episode 78/100 :: High Score - 22
# Episode 79/100 :: High Score - 18
# Episode 80/100 :: High Score - 13
# Episode 81/100 :: High Score - 14
# Episode 82/100 :: High Score - 56
# Episode 83/100 :: High Score - 18
# Episode 84/100 :: High Score - 32
# Episode 85/100 :: High Score - 19
# Episode 86/100 :: High Score - 15
# Episode 87/100 :: High Score - 19
# Episode 88/100 :: High Score - 13
# Episode 89/100 :: High Score - 25
# Episode 90/100 :: High Score - 27
# Episode 91/100 :: High Score - 11
# Episode 92/100 :: High Score - 27
# Episode 93/100 :: High Score - 14
# Episode 94/100 :: High Score - 16
# Episode 95/100 :: High Score - 48
# Episode 96/100 :: High Score - 8
# Episode 97/100 :: High Score - 15
# Episode 98/100 :: High Score - 8
# Episode 99/100 :: High Score - 27

# %%
from collections import deque
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam
import numpy as np
import random
import os

# %% [markdown]
# ## Agent Class

# %%
class Agent:
    def __init__(self,state_size,action_size):
        self.state_size=state_size
        self.action_size=action_size
        self.memory=deque(maxlen=2000)
        self.epsilon=1.0
        self.epsilon_decay=0.995
        self.epsilon_min=0.1
        self.gamma=0.95 ## Discount factor
        self.model = self._create_model()
    
    def _create_model(self):
        #neural network to approximate Q-learning Function
        model=Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu'))
        model.add(Dense(48,activation='tanh'))
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(optimizer=Adam(lr=0.001),loss='mse')
        return model
    
    def remember(self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward,next_state,done)) # remember previous experiences
        
    def act(self,state):
        if np.random.rand()<self.epsilon:
            return random.randrange(self.action_size)
        action = self.model.predict(state)
        return np.argmax(action[0])
    
    def train(self,batch_size=32):
        minibatch=random.sample(self.memory,batch_size)
        
        for state,action,reward,next_state,done in minibatch:
            if not done:
                target = reward + self.gamma*np.amax(self.model.predict(next_state)[0])
            else:
                target = reward
            
            target_f = self.model.predict(state)
            target_f[0][action] = target
            
            self.model.fit(state,target_f,epochs=1,verbose=0)
            
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
            
    def load(self,name):
        self.model.load_weights(name)
        
    def save(self,name):
        self.model.save_weights(name)

# %%
n_episodes = 1000
#os.mkdir('cartpole_model/')
output_dir = "cartpole_model/"

state_size = 4
action_size =2
batch_size = 32

agent = Agent(state_size, action_size) # initialise agent
done = False
for e in range(n_episodes):
    state = env.reset()
    state = np.reshape(state,[1,state_size])
    
    for time in range(5000):
        env.render()
        action = agent.act(state) #action is 0 or 1
        next_state,reward,done,other_info = env.step(action) 
        reward = reward if not done else -10
        next_state = np.reshape(next_state,[1,state_size])
        agent.remember(state,action,reward,next_state,done)
        state = next_state
        
        if done:
            print("Game Episode :{}/{}, High Score:{},Exploration Rate:{:.2}".format(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory)>batch_size:
        agent.train(batch_size)
    
    if e%50==0:
        agent.save(output_dir+"weights_"+'{:04d}'.format(e)+".hdf5")
        
env.close()
# Out:
# Game Episode :0/100, High Score:17,Exploration Rate:1.0
# Game Episode :1/100, High Score:14,Exploration Rate:1.0
# Game Episode :2/100, High Score:22,Exploration Rate:0.99
# Game Episode :3/100, High Score:18,Exploration Rate:0.99
# Game Episode :4/100, High Score:48,Exploration Rate:0.99
# Game Episode :5/100, High Score:34,Exploration Rate:0.98
# Game Episode :6/100, High Score:14,Exploration Rate:0.98
# Game Episode :7/100, High Score:13,Exploration Rate:0.97
# Game Episode :8/100, High Score:21,Exploration Rate:0.97
# Game Episode :9/100, High Score:17,Exploration Rate:0.96
# Game Episode :10/100, High Score:11,Exploration Rate:0.96
# Game Episode :11/100, High Score:15,Exploration Rate:0.95
# Game Episode :12/100, High Score:11,Exploration Rate:0.95
# Game Episode :13/100, High Score:11,Exploration Rate:0.94
# Game Episode :14/100, High Score:10,Exploration Rate:0.94
# Game Episode :15/100, High Score:15,Exploration Rate:0.93
# Game Episode :16/100, High Score:10,Exploration Rate:0.93
# Game Episode :17/100, High Score:18,Exploration Rate:0.92
# Game Episode :18/100, High Score:11,Exploration Rate:0.92
# Game Episode :19/100, High Score:18,Exploration Rate:0.91
# Game Episode :20/100, High Score:24,Exploration Rate:0.91
# Game Episode :21/100, High Score:38,Exploration Rate:0.9
# Game Episode :22/100, High Score:26,Exploration Rate:0.9
# Game Episode :23/100, High Score:15,Exploration Rate:0.9
# Game Episode :24/100, High Score:19,Exploration Rate:0.89
# Game Episode :25/100, High Score:9,Exploration Rate:0.89
# Game Episode :26/100, High Score:13,Exploration Rate:0.88
# Game Episode :27/100, High Score:31,Exploration Rate:0.88
# Game Episode :28/100, High Score:44,Exploration Rate:0.87
# Game Episode :29/100, High Score:15,Exploration Rate:0.87
# Game Episode :30/100, High Score:42,Exploration Rate:0.86
# Game Episode :31/100, High Score:9,Exploration Rate:0.86
# Game Episode :32/100, High Score:39,Exploration Rate:0.86
# Game Episode :33/100, High Score:42,Exploration Rate:0.85
# Game Episode :34/100, High Score:25,Exploration Rate:0.85
# Game Episode :35/100, High Score:11,Exploration Rate:0.84
# Game Episode :36/100, High Score:13,Exploration Rate:0.84
# Game Episode :37/100, High Score:15,Exploration Rate:0.83
# Game Episode :38/100, High Score:53,Exploration Rate:0.83
# Game Episode :39/100, High Score:61,Exploration Rate:0.83
# Game Episode :40/100, High Score:52,Exploration Rate:0.82
# Game Episode :41/100, High Score:24,Exploration Rate:0.82
# Game Episode :42/100, High Score:28,Exploration Rate:0.81
# Game Episode :43/100, High Score:14,Exploration Rate:0.81
# Game Episode :44/100, High Score:38,Exploration Rate:0.81
# Game Episode :45/100, High Score:15,Exploration Rate:0.8
# Game Episode :46/100, High Score:86,Exploration Rate:0.8
# Game Episode :47/100, High Score:20,Exploration Rate:0.79
# Game Episode :48/100, High Score:14,Exploration Rate:0.79
# Game Episode :49/100, High Score:13,Exploration Rate:0.79
# Game Episode :50/100, High Score:15,Exploration Rate:0.78
# Game Episode :51/100, High Score:46,Exploration Rate:0.78
# Game Episode :52/100, High Score:18,Exploration Rate:0.77
# Game Episode :53/100, High Score:14,Exploration Rate:0.77
# Game Episode :54/100, High Score:20,Exploration Rate:0.77
# Game Episode :55/100, High Score:16,Exploration Rate:0.76
# Game Episode :56/100, High Score:19,Exploration Rate:0.76
# Game Episode :57/100, High Score:23,Exploration Rate:0.76
# Game Episode :58/100, High Score:79,Exploration Rate:0.75
# Game Episode :59/100, High Score:27,Exploration Rate:0.75
# Game Episode :60/100, High Score:27,Exploration Rate:0.74
# Game Episode :61/100, High Score:15,Exploration Rate:0.74
# Game Episode :62/100, High Score:14,Exploration Rate:0.74
# Game Episode :63/100, High Score:33,Exploration Rate:0.73
# Game Episode :64/100, High Score:9,Exploration Rate:0.73
# Game Episode :65/100, High Score:23,Exploration Rate:0.73
# Game Episode :66/100, High Score:11,Exploration Rate:0.72
# Game Episode :67/100, High Score:27,Exploration Rate:0.72
# Game Episode :68/100, High Score:13,Exploration Rate:0.71
# Game Episode :69/100, High Score:22,Exploration Rate:0.71
# Game Episode :70/100, High Score:21,Exploration Rate:0.71
# Game Episode :71/100, High Score:8,Exploration Rate:0.7
# Game Episode :72/100, High Score:50,Exploration Rate:0.7
# Game Episode :73/100, High Score:20,Exploration Rate:0.7
# Game Episode :74/100, High Score:25,Exploration Rate:0.69
# Game Episode :75/100, High Score:15,Exploration Rate:0.69
# Game Episode :76/100, High Score:30,Exploration Rate:0.69
# Game Episode :77/100, High Score:32,Exploration Rate:0.68
# Game Episode :78/100, High Score:36,Exploration Rate:0.68
# Game Episode :79/100, High Score:12,Exploration Rate:0.68
# Game Episode :80/100, High Score:13,Exploration Rate:0.67
# Game Episode :81/100, High Score:13,Exploration Rate:0.67
# Game Episode :82/100, High Score:117,Exploration Rate:0.67
# Game Episode :83/100, High Score:44,Exploration Rate:0.66
# Game Episode :84/100, High Score:24,Exploration Rate:0.66
# Game Episode :85/100, High Score:18,Exploration Rate:0.66
# Game Episode :86/100, High Score:24,Exploration Rate:0.65
# Game Episode :87/100, High Score:17,Exploration Rate:0.65
# Game Episode :88/100, High Score:61,Exploration Rate:0.65
# Game Episode :89/100, High Score:36,Exploration Rate:0.64
# Game Episode :90/100, High Score:68,Exploration Rate:0.64
# Game Episode :91/100, High Score:41,Exploration Rate:0.64
# Game Episode :92/100, High Score:77,Exploration Rate:0.63
# Game Episode :93/100, High Score:12,Exploration Rate:0.63
# Game Episode :94/100, High Score:20,Exploration Rate:0.63
# Game Episode :95/100, High Score:38,Exploration Rate:0.62
# Game Episode :96/100, High Score:24,Exploration Rate:0.62
# Game Episode :97/100, High Score:46,Exploration Rate:0.62
# Game Episode :98/100, High Score:27,Exploration Rate:0.61
# Game Episode :99/100, High Score:34,Exploration Rate:0.61
